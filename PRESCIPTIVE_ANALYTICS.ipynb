# %% [markdown]
# <a href="https://colab.research.google.com/github/VamseeBana/DATA-ANALYTICS-DAILY-TASK/blob/main/PRESCIPTIVE_ANALYTICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRESCRIPTIVE ANALYTICS

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(
    {
        "Name":["Alice","Bob","Claire","rao","raj","ravi"],
        "Age":[25,65,27,60,35,40],
        "condition":["normal","emergency","normal","emregncy","nomaral","emerency"],
        "oxygen_level":["medium","low","high","low","medium","medium"]

    }
)
avaible_beds=5
print(df)
# Out:
#      Name  Age  condition oxygen_level
# 0   Alice   25     normal       medium
# 1     Bob   65  emergency          low
# 2  Claire   27     normal         high
# 3     rao   60   emregncy          low
# 4     raj   35    nomaral       medium
# 5    ravi   40   emerency       medium

# %% [markdown]
# PRIOITY LEVEL CALCULATION

# %%
df["priority_level"] = 0
for i in range(6):
  if df["condition"][i]=="emergency" and df["oxygen_level"][i]=="low" and df["Age"][i]  >= 45:
    df["priority_level"][i]=1
  elif df["condition"][i]=="emergency" and df["oxygen_level"][i]=="high" and 35 >= df["Age"][i] <= 45:
    df["priority_level"][i]=2
  elif df["condition"][i]=="emergency" and df["oxygen_level"][i]=="medium" and df["Age"] <=35:
    df["priority_level"][i]=3
# Out:
# /tmp/ipykernel_865/3069281975.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["priority_level"][i]=1
# /tmp/ipykernel_865/3069281975.py:4: SettingWithCopyWarning:
# ...

# %%
r = 0
available_beds = 6
df.loc[i, "priority_level"] = int(input("Enter priority (1/2/3): "))

if df.loc[i, "priority_level"] == 1:
    print("allocated bed")
    r += 1

elif df.loc[i, "priority_level"] == 2:
    print("allocated bed")
    r += 1
elif df.loc[i, "priority_level"] == 3:
    print("allocated bed")
    r += 1
else:
    print("sorry no beds available")
if r > available_beds:
    print("sorry no beds available")
# Out:
# Enter priority (1/2/3): 5
# sorry no beds available
